# %% [markdown]
# **Quantum Computing and Informatics**
# > **Teacher Assistent: Sthefanie Passo**
#
# > **E-mail: sthefanie.passo@utsa.edu**
#
# # Install Qiskit and Setup Jupyter Notebook
#
# ### How to install Jupyter in your local computer
#
# First install Anaconda Python Distribution at [www.anaconda.com/download](https://www.anaconda.com/download)
#
# ### Install Qiskit
#
# Once the installation is complete, launch the “**Anaconda Prompt**”
#
# In the anaconda prompt, type “**pip install qiskit**”
# ![link text](https://miro.medium.com/v2/resize:fit:1200/1*slrJOCdCaWt2BJfHqdiXTQ.png)
#
#
# ### Launch Jupyter Notebook
# Launch the Jupyter Notebook by just typing the command “**jupyter notebook**”
#
# Now create a new Python 3 Notebook by clicking New > Python 3

# %% [markdown]
# HXH = Z

# %% [markdown]
# ### Colaboratory is another option
#
# Although  there is an online version of Jupyter Notebooks that allows for collaborative and real-time edition of your notebooks [Google Colaboratory](https://colab.research.google.com/)!
#
# For this class we will be using the Google Colaboratory and Qiskit.
#
# ![link text](https://miro.medium.com/v2/resize:fit:986/1*pimj8lXWwZnqLs2xVCV2Aw.png)

# %% [markdown]
# ## Qiskit Sign Up
#
# Go to [https://quantum.ibm.com/](https://quantum.ibm.com/) and **create your account**
#
# Click on the user icon on the top right corner and
# select "**My Account**"
#
# Click the "**Copy token**" (blue button) to copy your API token to the clipboard
#
# Go back tou your Colab and import IBMQ from Qiskit by typing the below line in the Jupyter Notebook and hit “**Shift"+Enter**”
#
# ```
# !pip install qiskit
#
# import qiskit
# ```
#
# ![link text](https://quantum.ibm.com/_nuxt/img/platformDarkScreenshot.ac4ed2c.png)

# %% [markdown]
# # Qiskit Libraries
#
# Before we start coding, we need to install qiskit

# %%
# !pip install qiskit
# !pip install qiskit_ibm_runtime
# Out:
# Requirement already satisfied: qiskit in c:\users\lhlee\miniconda3\lib\site-packages (1.4.3)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit) (0.16.0)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit) (2.3.1)
# Requirement already satisfied: scipy>=1.5 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit) (1.16.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit) (1.14.0)
# Requirement already satisfied: dill>=0.3 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit) (5.4.1)
# Requirement already satisfied: typing-extensions in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit) (4.12.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit) (0.13.0)
# Requirement already satisfied: six>=1.5 in c:\users\lhlee\miniconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\lhlee\miniconda3\lib\site-packages (from stevedore>=3.0.0->qiskit) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lhlee\miniconda3\lib\site-packages (from sympy>=1.3->qiskit) (1.3.0)
# Requirement already satisfied: setuptools in c:\users\lhlee\miniconda3\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit) (78.1.1)
# Collecting qiskit_ibm_runtime
#   Downloading qiskit_ibm_runtime-0.40.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: requests>=2.19 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit_ibm_runtime) (2.32.3)
# Collecting requests-ntlm>=1.1.0 (from qiskit_ibm_runtime)
#   Downloading requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.13 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit_ibm_runtime) (2.3.1)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit_ibm_runtime) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit_ibm_runtime) (2.9.0.post0)
# Collecting ibm-platform-services>=0.22.6 (from qiskit_ibm_runtime)
#   Downloading ibm_platform_services-0.66.2-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pydantic>=2.5.0 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit_ibm_runtime) (2.10.3)
# Requirement already satisfied: qiskit>=1.4.1 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit_ibm_runtime) (1.4.3)
# Requirement already satisfied: packaging in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit_ibm_runtime) (24.2)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.2 (from ibm-platform-services>=0.22.6->qiskit_ibm_runtime)
#   Downloading ibm_cloud_sdk_core-3.24.2-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lhlee\miniconda3\lib\site-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\lhlee\miniconda3\lib\site-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\lhlee\miniconda3\lib\site-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\lhlee\miniconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit_ibm_runtime) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (0.16.0)
# Requirement already satisfied: scipy>=1.5 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (1.16.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (1.14.0)
# Requirement already satisfied: dill>=0.3 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (5.4.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\lhlee\miniconda3\lib\site-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lhlee\miniconda3\lib\site-packages (from requests>=2.19->qiskit_ibm_runtime) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lhlee\miniconda3\lib\site-packages (from requests>=2.19->qiskit_ibm_runtime) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lhlee\miniconda3\lib\site-packages (from requests>=2.19->qiskit_ibm_runtime) (2025.6.15)
# Requirement already satisfied: cryptography>=1.3 in c:\users\lhlee\miniconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (44.0.1)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Downloading pyspnego-0.11.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\lhlee\miniconda3\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (1.17.1)
# Collecting requests>=2.19 (from qiskit_ibm_runtime)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting urllib3>=1.21.1 (from qiskit_ibm_runtime)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting PyJWT<3.0.0,>=2.10.1 (from ibm_cloud_sdk_core<4.0.0,>=3.24.2->ibm-platform-services>=0.22.6->qiskit_ibm_runtime)
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting sspilib>=0.1.0 (from pyspnego>=0.4.0->requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Downloading sspilib-0.3.1-cp313-cp313-win_amd64.whl.metadata (6.2 kB)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\lhlee\miniconda3\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.4.1->qiskit_ibm_runtime) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lhlee\miniconda3\lib\site-packages (from sympy>=1.3->qiskit>=1.4.1->qiskit_ibm_runtime) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\lhlee\miniconda3\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (2.21)
# Requirement already satisfied: setuptools in c:\users\lhlee\miniconda3\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit>=1.4.1->qiskit_ibm_runtime) (78.1.1)
# Downloading qiskit_ibm_runtime-0.40.1-py3-none-any.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.2 MB 1.1 MB/s eta 0:00:03
#    --------- ------------------------------ 0.8/3.2 MB 1.2 MB/s eta 0:00:03
#    ------------- -------------------------- 1.0/3.2 MB 1.2 MB/s eta 0:00:02
#    ------------------- -------------------- 1.6/3.2 MB 1.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.8/3.2 MB 1.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.4/3.2 MB 1.5 MB/s eta 0:00:01
#    -------------------------------- ------- 2.6/3.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  3.1/3.2 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 1.6 MB/s eta 0:00:00
# Downloading ibm_platform_services-0.66.2-py3-none-any.whl (363 kB)
# Downloading requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Downloading ibm_cloud_sdk_core-3.24.2-py3-none-any.whl (75 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading pyspnego-0.11.2-py3-none-any.whl (130 kB)
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading sspilib-0.3.1-cp313-cp313-win_amd64.whl (620 kB)
#    ---------------------------------------- 0.0/620.8 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/620.8 kB ? eta -:--:--
#    ---------------------------------------- 620.8/620.8 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: urllib3, sspilib, PyJWT, requests, pyspnego, ibm_cloud_sdk_core, requests-ntlm, ibm-platform-services, qiskit_ibm_runtime
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# Successfully installed PyJWT-2.10.1 ibm-platform-services-0.66.2 ibm_cloud_sdk_core-3.24.2 pyspnego-0.11.2 qiskit_ibm_runtime-0.40.1 requests-2.32.4 requests-ntlm-1.3.0 sspilib-0.3.1 urllib3-2.5.0

# %% [markdown]
# After we need to import the libraries that are needed

# %%
import qiskit
from qiskit_ibm_runtime import QiskitRuntimeService

# %% [markdown]
# You now have an IBM Q Experience's **API token, save** it to your computer by typing the bellow line and hit **Shift+Enter**

# %%
token = "79232e64fa632d6dc52dbcba74585a33ec8593fe06d654771e8e3805d1cfb4f029a8d2b4dc022194164e29c2c16746342a7abc849cac0e6d9b2a726ab4785731"
service = QiskitRuntimeService(channel = "ibm_quantum", token = token)

# %% [markdown]
# # Quantum Backend
#
# To view the backends you have access to, you can either view a list on the Compute resources page, or you can use the **QiskitRuntimeService.backends()** method. This method returns a list of IBMBackend instances:

# %%
all = service.backends()

# %%
all
# Out:
# [<IBMBackend('ibm_brisbane')>, <IBMBackend('ibm_sherbrooke')>]

# %% [markdown]
# The **QiskitRuntimeService.backend()** method (note that this is singular: backend) takes the name of the backend as the input parameter and returns an IBMBackend instance representing that particular backend:

# %%
service.backend("ibm_brisbane")
# Out:
# <IBMBackend('ibm_brisbane')>

# %% [markdown]
# ### Filter backends
#
# You can also filter the available backends by their properties. For more general **filters**, set the filters argument to a function that accepts a backend object and returns **True** if it meets your criteria. Refer to the API documentation for more details.
#
# The following code returns only backends that fit these criteria:
#
#
# ```
# Are real quantum devices (simulator=False)
# Are currently operational (operational=True)
# Have at least 5 qubits (min_num_qubits=5)
# ```

# %%
service.backends(simulator=True, operational=False, min_num_qubits=5)
# Out:
# []

# %% [markdown]
# Use these keyword arguments to filter by any attribute in backend configuration (JSON schema) or status (JSON schema). A similar method is **QiskitRuntimeService.least_busy()**, which takes the same filters as backends() but returns the backend that matches the filters and has the least number of jobs pending in the queue:

# %%
service.least_busy(simulator=False, operational=True, min_num_qubits=5)
# Out:
# <IBMBackend('ibm_brisbane')>

# %% [markdown]
# ## Static backend information
#
# Some information about a backend does not change regularly, such as its name, version, the number of qubits it has, and the types of features it supports. This information is available as attributes of the **backend** object.
#
# The following cell builds a description of a backend.

# %%
backend = service.backend("ibm_sherbrooke")

print(
    f"Name: {backend.name}\n"
    f"Version: {backend.version}\n"
    f"No. of qubits: {backend.num_qubits}\n"
)
# Out:
# Name: ibm_sherbrooke
# Version: 2
# No. of qubits: 127

# %%
backend = service.backend("ibm_brisbane")

print(
    f"Name: {backend.name}\n"
    f"Version: {backend.version}\n"
    f"No. of qubits: {backend.num_qubits}\n"
)
# Out:
# Name: ibm_brisbane
# Version: 2
# No. of qubits: 127

# %% [markdown]
# # Creating our first circuit
#
# For a full list of attributes, see the IBMBackend API [documentation](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.IBMBackend).

# %%
#!pip install pylatexenc

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\lhlee\miniconda3\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lhlee\miniconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\lhlee\miniconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lhlee\miniconda3\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lhlee\miniconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\lhlee\miniconda3\lib\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\lhlee\miniconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\lhlee\miniconda3\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lhlee\miniconda3\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lhlee\miniconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lhlee\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install pylatexenc
# Out:
# Requirement already satisfied: pylatexenc in c:\users\lhlee\miniconda3\lib\site-packages (2.10)

# %%
# %matplotlib inline
# Importing standard Qiskit libraries and configuring account
from qiskit import QuantumRegister,ClassicalRegister,QuantumCircuit
from qiskit.compiler import transpile, assemble
import matplotlib.pyplot as plt

# Loading your IBM Q account(s)

# We create a quantum circuit that is made up of the quantum register and the classic register
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
circuit = QuantumCircuit(qr,cr)
# Add gates to the quantum circuit circuit.x(qr[1])
circuit.barrier()
circuit.h(qr[0])
circuit.h(qr[1])
circuit.cx(qr[0],qr[1]) #qr1 is target/ qr0 is control bit
circuit.h(qr[0])
circuit.h(qr[1])
circuit.barrier()
circuit.measure(qr,cr)
circuit.draw("mpl")#sytle
# Out:
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[8], line 22
#      20 circuit.barrier()
#      21 circuit.measure(qr,cr)
# ---> 22 circuit.draw("mpl")#sytle
#
# File c:\Users\lhlee\miniconda3\Lib\site-packages\qiskit\circuit\quantumcircuit.py:3428, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len)
#    3425 # pylint: disable=cyclic-import
#    3426 from qiskit.visualization import circuit_drawer
# -> 3428 return circuit_drawer(
#    3429     self,
#    3430     scale=scale,
#    3431     filename=filename,
#    3432     style=style,
#    3433     output=output,
#    3434     interactive=interactive,
#    3435     plot_barriers=plot_barriers,
#    3436     reverse_bits=reverse_bits,
#    3437     justify=justify,
#    3438     vertical_compression=vertical_compression,
#    3439     idle_wires=idle_wires,
#    3440     with_layout=with_layout,
#    3441     fold=fold,
#    3442     ax=ax,
#    3443     initial_state=initial_state,
#    3444     cregbundle=cregbundle,
#    3445     wire_order=wire_order,
#    3446     expr_len=expr_len,
#    3447 )
#
# File c:\Users\lhlee\miniconda3\Lib\site-packages\qiskit\visualization\circuit\circuit_visualization.py:332, in circuit_drawer(circuit, scale, filename, style, output, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len)
#     317     return _generate_latex_source(
#     318         circuit,
#     319         filename=filename,
#    (...)    329         wire_order=complete_wire_order,
#     330     )
#     331 elif output == "mpl":
# --> 332     image = _matplotlib_circuit_drawer(
#     333         circuit,
#     334         scale=scale,
#     335         filename=filename,
#     336         style=style,
#     337         plot_barriers=plot_barriers,
#     338         reverse_bits=reverse_bits,
#     339         justify=justify,
#     340         idle_wires=idle_wires,
#     341         with_layout=with_layout,
#     342         fold=fold,
#     343         ax=ax,
#     344         initial_state=initial_state,
#     345         cregbundle=cregbundle,
#     346         wire_order=complete_wire_order,
#     347         expr_len=expr_len,
#     348     )
#     349 else:
#     350     raise VisualizationError(
#     351         f"Invalid output type {output} selected. The only valid choices "
#     352         "are text, latex, latex_source, and mpl"
#     353     )
#
# File c:\Users\lhlee\miniconda3\Lib\site-packages\qiskit\visualization\circuit\circuit_visualization.py:712, in _matplotlib_circuit_drawer(circuit, scale, filename, style, plot_barriers, reverse_bits, justify, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len)
#     709 if fold is None:
#     710     fold = 25
# --> 712 qcd = _matplotlib.MatplotlibDrawer(
#     713     qubits,
#     714     clbits,
#     715     nodes,
#     716     circuit,
#     717     scale=scale,
#     718     style=style,
#     719     reverse_bits=reverse_bits,
#     720     plot_barriers=plot_barriers,
#     721     fold=fold,
#     722     ax=ax,
#     723     initial_state=initial_state,
#     724     cregbundle=cregbundle,
#     725     with_layout=with_layout,
#     726     expr_len=expr_len,
#     727 )
#     728 return qcd.draw(filename)
#
# File c:\Users\lhlee\miniconda3\Lib\site-packages\qiskit\utils\classtools.py:111, in _WrappedMethod.__get__.<locals>.out(*args, **kwargs)
#     108 @functools.wraps(method)
#     109 def out(*args, **kwargs):
#     110     for callback in self._before:
# --> 111         callback.__get__(obj, objtype)(*args, **kwargs)
#     112     retval = method(*args, **kwargs)
#     113     for callback in self._after:
#
# File c:\Users\lhlee\miniconda3\Lib\site-packages\qiskit\utils\lazy_tester.py:41, in _RequireNow.__call__(self, *_args, **_kwargs)
#      40 def __call__(self, *_args, **_kwargs):
# ---> 41     self._tester.require_now(self._feature)
#
# File c:\Users\lhlee\miniconda3\Lib\site-packages\qiskit\utils\lazy_tester.py:221, in LazyDependencyManager.require_now(self, feature)
#     219 if self:
#     220     return
# --> 221 raise MissingOptionalLibraryError(
#     222     libname=self._name, name=feature, pip_install=self._install, msg=self._msg
#     223 )
#
# MissingOptionalLibraryError: "The 'pylatexenc' library is required to use 'MatplotlibDrawer'. You can install it with 'pip install pylatexenc'."

# %% [markdown]
# If the draw does not work: "you must restart your notebook kernel and run again. It worked for me!" [Stakoverflow](https://stackoverflow.com/questions/68954685/qiskit-mpl-drawer-module)

# %% [markdown]
# Set the backend on which to run.
#
# Please first check which backends are available for you by running the below codes, then use that one which is available.

# %%
all
# Out:
# [<IBMBackend('ibm_brisbane')>, <IBMBackend('ibm_sherbrooke')>]

# %%
from qiskit_ibm_runtime import qiskit_runtime_service, SamplerV2 as Sampler
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

backend = service.backend("ibm_brisbane")

# %% [markdown]
# Create a quantum job for the circuit

# %%
# Optimize the circuit using a preset pass manager
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
optimized_circuit = pm.run(circuit)

# Initialize the sampler and run the job
sampler = Sampler(backend)
job = sampler.run([optimized_circuit])
result = job.result()

# %%
# Get the result counts for the quantum circuit
pub_result = result[0]
counts = pub_result.data.c1.get_counts()
print(f" >> Measurement results: {counts}")
# Out:
#  >> Measurement results: {'01': 19, '00': 3533, '10': 518, '11': 26}

# %% [markdown]
# You can also plot the result to be easier to understand

# %%
pub_result.data.c1.get_counts()
print(f" >> Measurement results: {counts}")

from qiskit.visualization import plot_histogram
plot_histogram(counts)
# Out:
#  >> Measurement results: {'00': 3885, '01': 195, '11': 9, '10': 7}

# %%
3885+195+7+9
# Out:
# 4096

# %% [markdown]
# Here is another example:

# %%
from qiskit import ClassicalRegister, QuantumRegister, QuantumCircuit
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler

# %%
alpha = ClassicalRegister(5, "alpha")
beta = ClassicalRegister(7, "beta")
qreg = QuantumRegister(12)

circuit = QuantumCircuit(qreg, alpha, beta)
circuit.h(0)#qubit 0
circuit.measure(qreg[:5], alpha)
circuit.measure(qreg[5:], beta)
circuit.draw('mpl')

# %%
service = QiskitRuntimeService(channel="ibm_quantum", token="79232e64fa632d6dc52dbcba74585a33ec8593fe06d654771e8e3805d1cfb4f029a8d2b4dc022194164e29c2c16746342a7abc849cac0e6d9b2a726ab4785731")
backend = service.least_busy(operational=True, simulator=False, min_num_qubits=12)
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

sampler = Sampler(backend)
job = sampler.run([isa_circuit])
result = job.result()
# Get results for the first (and only) PUB
pub_result = result[0]
print(f" >> Counts for the alpha output register: {pub_result.data.alpha.get_counts()}")
print(f" >> Counts for the beta output register: {pub_result.data.beta.get_counts()}")
# Out:
# /Users/sthefaniepasso/Library/Python/3.9/lib/python/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:919: UserWarning: IBM Quantum Platform is moving, and this version will be sunset on July 1. To get started on the new platform, read the migration guide at https://docs.quantum.ibm.com/migration-guides/classic-iqp-to-cloud-iqp
#   warnings.warn(warning_message)
#  >> Counts for the alpha output register: {'00000': 1792, '00001': 2025, '00010': 33, '00011': 18, '01001': 72, '10001': 23, '10000': 25, '01000': 77, '00101': 13, '01010': 1, '00100': 10, '01011': 2, '01101': 1, '01100': 2, '11001': 1, '00110': 1}
#  >> Counts for the beta output register: {'0000000': 3733, '1000000': 208, '0010000': 26, '0000010': 15, '0000001': 28, '0000100': 25, '0100000': 33, '1000100': 5, '1000001': 4, '0001000': 13, '0001001': 1, '0100001': 1, '1100000': 1, '1000010': 1, '0101000': 1, '1010000': 1}

# %%
from qiskit.visualization import plot_histogram

counts1 = pub_result.data.alpha.get_counts()
plot_histogram(counts1)

# %%
counts2 = pub_result.data.beta.get_counts()

plot_histogram(counts2)

# %% [markdown]
# # Example with Many Quantum Gates:
#
# Below is a quantum circuit example that uses various quantum gates. This example demonstrates how to apply multiple gate types in a circuit. The gates used are: **Hadamard (H), Pauli-X (X), Pauli-Y (Y), Pauli-Z (Z), Controlled-NOT (CX), Swap (SWAP), and T-gate (T)**.
#
# ![link text](https://upload.wikimedia.org/wikipedia/commons/thumb/e/e0/Quantum_Logic_Gates.png/440px-Quantum_Logic_Gates.png)
#
# Here is a circuit example of how to apply all this gates:

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.visualization import plot_histogram 
import matplotlib.pyplot as plt

#creating a quantum and classical registers
qr = QuantumRegister(3,'q')
cr = ClassicalRegister(3, 'c')

#creating the circuit diagram 
circuit = QuantumCircuit(qr, cr)

#adding the logic gates
circuit.barrier()
circuit.x(qr[0])
circuit.x(qr[0])
circuit.x(qr[1])
circuit.y(qr[1])
circuit.t(qr[1])
circuit.z(qr[2])
circuit.h(qr[2])
circuit.cx(qr[0], qr[2])
circuit.swap(qr[0], qr[1])
circuit.tdg(qr[2])  #tdg = t dagger, T- gate 
circuit.barrier()

#measuring the circuit 
circuit.measure(qr[0], cr[0])
circuit.measure(qr[1], cr[1])
circuit.measure(qr[2], cr[2])

#drawing the circuit 

circuit.draw('mpl')

# %% [markdown]
# This circuit applies several different gates on 3 qubits and ends by measuring all qubits. Below are two exercises that will help students practice these gates.
#
# ## Exercise 1: Bell State with Swap Gate
#
# Objective: Create a quantum circuit that generates a Bell state between two qubits and then swaps their states.
#
# Instructions:
#
# 	1.	Start by applying a Hadamard gate to the first qubit to create a superposition.
# 	2.	Apply a Controlled-NOT (CX) gate between the first and second qubits to entangle them.
# 	3.	Use a Swap gate to swap the states of the second and third qubits.
# 	4.	Measure the qubits and visualize the results.
#
# Hints:
#
# 	•	Use the h() gate to apply a Hadamard gate.
# 	•	Use the cx() gate to apply a CNOT gate.
# 	•	Use the swap() gate to apply a SWAP gate.
# 	•	Use the measure() function to measure the qubits.

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.visualization import plot_histogram 
import matplotlib.pyplot as plt 


# Creating the quantum and classical registers 
qr = QuantumRegister(3, 'q')
cr = ClassicalRegister(3, 'c')

#creat quantum circuit 
circuit = QuantumCircuit(qr, cr)

#apllying gates
circuit.barrier()
circuit.h(qr[0])
circuit.cx(qr[0], qr[1])
circuit.swap(qr[1], qr[2])
circuit.barrier()

#measure
circuit.measure(qr, cr)

#draw the circuit 
circuit.draw('mpl')

# %%
service = QiskitRuntimeService(channel="ibm_quantum", token="79232e64fa632d6dc52dbcba74585a33ec8593fe06d654771e8e3805d1cfb4f029a8d2b4dc022194164e29c2c16746342a7abc849cac0e6d9b2a726ab4785731")
backend = service.least_busy(operational=True, simulator=False, min_num_qubits=12)
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

sampler = Sampler(backend)
job = sampler.run([isa_circuit])
result = job.result()
# Get results for the first (and only) PUB
pub_result = result[0]
print(f" >> Counts for the c output register: {pub_result.data.c.get_counts()}")
# Out:
# /Users/sthefaniepasso/Library/Python/3.9/lib/python/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:919: UserWarning: IBM Quantum Platform is moving, and this version will be sunset on July 1. To get started on the new platform, read the migration guide at https://docs.quantum.ibm.com/migration-guides/classic-iqp-to-cloud-iqp
#   warnings.warn(warning_message)
#  >> Counts for the c output register: {'101': 1291, '000': 1380, '001': 343, '111': 226, '010': 256, '011': 111, '110': 185, '100': 304}

# %% [markdown]
# ## Exercise 2: Implementing a Qiskit Circuit from a Circuit Plot
#
# Objective:
#
# Implement the Qiskit circuit that matches the quantum circuit plot shown below. The circuit involves 4 qubits and uses a combination of Pauli-X (X), CNOT (CX), Measure and Barrier.
#
# ![link text](https://i.sstatic.net/fIVoY.png)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.visualization import plot_histogram 
import matplotlib.pyplot as plt


#creating the quantum and classical registers
qr = QuantumRegister(4, 'q')
cr = ClassicalRegister(2, 'c')

#creating circuit 
circuit = QuantumCircuit(qr, cr)

#applying various gates
circuit.x(qr[0])
circuit.x(qr[1])
circuit.barrier()
circuit.cx(qr[0], qr[2])
circuit.cx(qr[1], qr[2])
circuit.ccx(qr[0],qr[1], qr[3])
circuit.barrier()

#measure 
circuit.measure(qr[2], cr[0])
circuit.measure(qr[3], cr[1])

#draw circuit 
circuit.draw('mpl')

# %% [markdown]
# **QuantumRegister** – this is a class that holds our qubits.
#
# **QuantumCircuit** – we will store opera!ons into QuantumCircuits.
#
# **execute** – this is a function that we must import in order to run our quantum algorithms.
#
#
# Review
#
# In order to run a circuit with success i=on qiskit quantum computers we need to keep in mind the following steps:
#
# ```
# - Import the libraries
# - Connect our accont by token
# - Get the backend
# - Create a quantum ciscuit using qiskit tools
# - Run a job
# - Plot the results
#
# ```
#
# This steps wil help you remember what you need to do, create your code and evaluate it.
#
#
#
#
#
#
# References:
#
# [Intall Qiskit](https://docs.quantum.ibm.com/guides/install-qiskit)
#
# [Get backend information with Qiskit](https://docs.quantum.ibm.com/guides/get-qpu-information)
#
# [Migrate to the Qiskit Runtime V2 primitives](https://docs.quantum.ibm.com/migration-guides/v2-primitives)
#
# [IBMQJob](https://docs.quantum.ibm.com/api/qiskit/0.19/qiskit.providers.ibmq.job.IBMQJob)
#
# [Catalog](https://learning.quantum.ibm.com/catalog/tutorials)
#
# [Qiskit Tutorials on Github](https://github.com/Qiskit/qiskit-tutorials/blob/master/tutorials/circuits/01_circuit_basics.ipynb)

# %% [markdown]
# Excersise 4
# ![](https://computationalmindset.com/posts/quantum-computing/hadamard-gate-cascade/qc-hdmgatecsd-circuit.png)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.visualization import plot_histogram 
import matplotlib.pyplot as plt


#creating the quantum and classical registers
qr = QuantumRegister(5, 'q')
cr = ClassicalRegister(5, 'c')

#creating circuit 
circuit = QuantumCircuit(qr, cr)

#applying the gates
circuit.barrier()
circuit.h(qr[0])   #0th quibit
circuit.h(qr[1])   #1st quibit 
circuit.h(qr[1])
circuit.x(qr[2])   #2nd quibit
circuit.x(qr[3])   #3rd quibit 
circuit.h(qr[3])  
circuit.x(qr[4])   #4th quibit 
circuit.h(qr[4])
circuit.h(qr[4])
circuit.h(qr[4])
circuit.barrier()

#measuring the circuit 
circuit.measure(qr[0], cr[0])
circuit.measure(qr[1], cr[1])
circuit.measure(qr[2], cr[2])
circuit.measure(qr[3], cr[3])
circuit.measure(qr[4], cr[4])

#drawing the circuit
circuit.draw('mpl')

# %% [markdown]
# Information about the circuit:
# q0: 0 -> (|0> + |1>)/sqrt(2) -> 50% for 0 and 1
# q1: 0 -> 0
# q2: 0 -> 1
# q3: 0 -> 1 -> (|0> - |1>)/sqrt(2) -> 50% for 0 and 1
# q4: 0 -> 1
# Final sequence: ?01?1=>00101,00111,10101,10111

# %%
service = QiskitRuntimeService(channel="ibm_quantum", token="79232e64fa632d6dc52dbcba74585a33ec8593fe06d654771e8e3805d1cfb4f029a8d2b4dc022194164e29c2c16746342a7abc849cac0e6d9b2a726ab4785731")
backend = service.least_busy(operational=True, simulator=False, min_num_qubits=12)
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

sampler = Sampler(backend)
job = sampler.run([isa_circuit], shots=10000)
result = job.result()
# Get results for the first (and only) PUB
pub_result = result[0]
print(f" >> Counts for the c output register: {pub_result.data.c.get_counts()}")
# print(f" >> Counts for the beta output register: {pub_result.data.beta.get_counts()}")
plot_histogram(pub_result.data.c.get_counts())
# Out:
# /Users/sthefaniepasso/Library/Python/3.9/lib/python/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:919: UserWarning: IBM Quantum Platform is moving, and this version will be sunset on July 1. To get started on the new platform, read the migration guide at https://docs.quantum.ibm.com/migration-guides/classic-iqp-to-cloud-iqp
#   warnings.warn(warning_message)
#  >> Counts for the c output register: {'10110': 194, '11101': 1880, '10100': 1280, '01100': 428, '11100': 1870, '10101': 1290, '11111': 283, '11001': 365, '11000': 353, '01001': 72, '01010': 15, '10000': 276, '01101': 411, '10111': 196, '01000': 89, '11110': 253, '10001': 270, '01111': 74, '10011': 35, '00111': 11, '00101': 51, '01110': 57, '00100': 47, '10010': 40, '11011': 52, '11010': 69, '00001': 7, '01011': 15, '00000': 10, '00110': 3, '00010': 2, '00011': 2}

# %%
plot_histogram(pub_result.data.c.get_counts())
#1st counter: 11101:947 X
#2nd counter: 10101:883 O
#Final sequence: ?01?1=>00101,00111,10101,10111
